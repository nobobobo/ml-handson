# %% [markdown]
# <a href="https://colab.research.google.com/github/nobobobo/ml-handson/blob/master/OpenCV_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OpenCV Demo

# %% [markdown]
# ## Import Libraries

# %%
# !pip install opencv-python
import cv2
print(cv2.__version__)
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.18.3)
# 4.1.2

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Import a picture

# %%
# from google.colab import files
# uploaded = files.upload()

# %%
ls asset/
# Out:
# noboru.jpg

# %%
img_bgr = cv2.imread('asset/noboru.jpg')
print(img_bgr)
# Out:
# [[[191 183 170]
#   [191 183 170]
#   [191 183 170]
#   ...
#   [226 171 102]
#   [226 171 102]
#   [226 171 102]]
#
#  [[191 183 170]
#   [191 183 170]
#   [191 183 170]
#   ...
#   [226 171 102]
#   [226 171 102]
#   [226 171 102]]
#
#  [[192 184 171]
#   [192 184 171]
#   [192 184 171]
#   ...
#   [226 171 102]
#   [226 171 102]
#   [226 171 102]]
#
#  ...
#
#  [[ 14   7   4]
#   [ 15   9   4]
#   [ 19  13   8]
#   ...
#   [ 85 101 160]
#   [ 67  91 157]
#   [ 43  68 140]]
#
#  [[ 12   7   6]
#   [ 11   6   3]
#   [ 12   8   3]
#   ...
#   [ 87 103 172]
#   [ 61  84 162]
#   [ 52  79 160]]
#
#  [[ 10   6   5]
#   [  8   5   1]
#   [  8   3   0]
#   ...
#   [ 93 110 183]
#   [ 63  87 171]
#   [ 52  79 166]]]

# %%
plt.imshow(img_bgr)
plt.show()

# %%
# print shape of img_bgr
x = np.array(img_bgr)
print(x.shape)
# Out:
# (960, 960, 3)

# %% [markdown]
# ## Convert the color of the picture

# %% [markdown]
# ### BGR to RGB

# %%
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# ### BGR to HSV

# %%
img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
plt.imshow(img_hsv)
plt.show()

# %% [markdown]
# ### RGB to GRAY

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)
plt.show()

# %%
cv2.imwrite('asset/hsv_noboru.jpg', img_hsv)
cv2.imwrite('asset/gray_noboru.jpg', img_gray)
# Out:
# True

# %%
ls asset/
# Out:
# gray_noboru.jpg  hsv_noboru.jpg  noboru.jpg

# %% [markdown]
# ## Trimming

# %%
size = img_rgb.shape
print(size)
# Out:
# (960, 960, 3)

# %%
top_left = img_rgb[:size[0]//2, :size[1]//2]
print(top_left.shape)
# Out:
# (480, 480, 3)

# %%
plt.imshow(top_left)
plt.show()

# %%
bottom_right = img_rgb[size[0]//2:, size[1]//2:]
plt.imshow(bottom_right)
plt.show()

# %% [markdown]
# ## Resizing

# %%
resized_img = cv2.resize(img_rgb, (img_rgb.shape[0]*2, img_rgb.shape[1]*2))
print(resized_img.shape)
# Out:
# (1920, 1920, 3)

# %%
plt.imshow(resized_img)
plt.show()

# %%
resized_img = cv2.resize(img_rgb, (img_rgb.shape[0]//10, img_rgb.shape[1]//10))
print(resized_img.shape)
plt.imshow(resized_img)
plt.show()
# Out:
# (96, 96, 3)

# %% [markdown]
# ## Rotating

# %%
mat = cv2.getRotationMatrix2D(tuple(np.array(img_rgb.shape[:2])/2), 45, 1.0)
result_img = cv2.warpAffine(img_rgb, mat, img_rgb.shape[:2])

plt.imshow(result_img)
plt.show()

# %%
mat = cv2.getRotationMatrix2D(tuple(np.array(img_rgb.shape[:2])/2), 135, .5)
result_img = cv2.warpAffine(img_rgb, mat, img_rgb.shape[:2])

plt.imshow(result_img)
plt.show()

# %% [markdown]
# ## Change color tone

# %%
result_img = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2LAB)

plt.imshow(result_img)
plt.show()

# %% [markdown]
# ## Binarization

# %%
## use cv2.threshold to binarize the image 

retval, result_img = cv2.threshold(img_rgb, 95, 128, cv2.THRESH_TOZERO)

plt.imshow(result_img)
plt.show()

# %%
retval, result_img = cv2.threshold(img_rgb, 100, 255, cv2.THRESH_BINARY)

plt.imshow(result_img)
plt.show()

# %% [markdown]
# ## Blurring

# %%
result_img = cv2.GaussianBlur(img_rgb, (15, 15), 0)

plt.imshow(result_img)
plt.show()

# %% [markdown]
# ## Denoising

# %%
result_img = cv2.fastNlMeansDenoisingColored(img_rgb)

plt.imshow(result_img)
plt.show()

# %% [markdown]
# ## Morphology Processing

# %% [markdown]
# ### Dilate

# %%
filt = np.array([[0,1,0],[1,0,1],[0,1,0]], np.uint8)

result_img = cv2.dilate(img_rgb, filt)

plt.imshow(result_img)
plt.show()

# %% [markdown]
# ### Erode

# %%
filt = np.array([[0,1,0],[1,0,1],[0,1,0]], np.uint8)

result_img = cv2.erode(img_rgb, filt)

plt.imshow(result_img)
plt.show()
